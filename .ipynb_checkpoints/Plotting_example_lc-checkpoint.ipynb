# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib
import feets
import os

script_dir = os.path.dirname('Results/')
results_dir = os.path.join(script_dir, 'Images/')

if not os.path.isdir(results_dir):
    os.makedirs(results_dir)

# %%
#### Uncomment to read-in the data

# # Reading in the data

url = "https://raw.githubusercontent.com/MachineLearningUniandes/MANTRA/master/data/lightcurves/transient_lightcurves.csv"
url1 = 'https://raw.githubusercontent.com/MachineLearningUniandes/MANTRA/master/data/lightcurves/transient_labels.csv'
url2 = 'https://raw.githubusercontent.com/MachineLearningUniandes/MANTRA/master/data/lightcurves/transient_info.txt'
transient_lc = pd.read_csv(url)
transient_labels = pd.read_csv(url1)
transient_info = pd.read_table(url2)

# %%
transient_labels.head(10)
transient_lc.head()
# Out:
#                           ID  observation_id      Mag    Magerr           MJD
# 0  TranID1409030010044114444               0  18.8765  0.166417  53766.089871
# 1  TranID1409030010044114444               1  20.0519  0.281733  53990.458866
# 2  TranID1409030010044114444               2  20.2199  0.295764  53996.286004
# 3  TranID1409030010044114444               3  21.1192  0.495390  54385.205789
# 4  TranID1409030010044114444               4  19.3289  0.195002  54355.282285

# %% [markdown]
# # Linking the uniques_IDs with the class

# %%
# Lb = []
# unique_ID = np.unique(transient_lc.ID)
# for i in range(len(transient_labels.Classification)):
    
#     for j in range(len(unique_ID)):
        
#         if unique_ID[j] == 'TranID' + str(transient_labels.TransientID.iloc[i]):
            
#             Lb.append(transient_labels.Classification[i])

# # Dictionary to store IDs and thier Class
# data = {'ID':unique_ID,'Class':Lb}
# # Classes based on the dictionary
# lc_class = pd.DataFrame(data)

# np.savetxt('LabelsID.csv', lc_class,delimiter=',',fmt='%s'
#            ,header='ID, Class')

# %%
data = pd.read_csv('LabelsID.csv',skiprows=1,names =['ID','Class'])

def lc_plots(lb,data,max_points):
    
    '''A function that plots light curves based on the input lables (i.e lb)

        Input: 

            .label: lb
            .data: data
            .maximum #points: max_points

        Output:

            . IDs of the plotted lc
            . Some lc plots

    '''


    Label = data[data['Class']==lb]


    plt.rcParams.update({'font.size': 20})
    plt.figure(figsize=(16,4))
    for i in range(len(Label)):

        # Lc for a specific ID
        lc = transient_lc[transient_lc['ID']==Label.ID.iloc[i]]

        if len(lc.ID) > max_points:

            plt.figure(figsize=(16,4))
            plt.errorbar(lc.MJD,lc.Mag,yerr=lc.Magerr,fmt='.r',label=lb)
            plt.legend(fontsize=12)
            plt.xlabel('MJD')
            plt.ylabel('Mag')

            print(lc.ID.iloc[0])

            plt.show()

                
lc_plots(lb='SN',data=data,max_points=450)
plt.show()
# Out:
# TranID1011081230504119481
# TranID1204111180464108242
# TranID1204111210464120236
# TranID1505121180464109343
# TranID1511141320394124088
# TranID1601211180424141819
# TranID1602261380334117968
# TranID803051320384107064

# %%
# Plotting the best 4 lc for a specific class

plt.figure(figsize=(22,10))

plt.subplot(221)
lc = transient_lc[transient_lc['ID']=='TranID1204111210464120236']
plt.errorbar(lc.MJD,lc.Mag,yerr=lc.Magerr,fmt='.r',label='SN')
plt.legend(fontsize=12)
plt.xlabel('MJD')
plt.ylabel('Mag')


plt.subplot(222)
lc = transient_lc[transient_lc['ID']=='TranID803051320384107064']
plt.errorbar(lc.MJD,lc.Mag,yerr=lc.Magerr,fmt='.r',label='SN')
plt.legend(fontsize=12)
plt.xlabel('MJD')
plt.ylabel('Mag')

plt.subplot(223)
lc = transient_lc[transient_lc['ID']=='TranID1011081230504119481']
plt.errorbar(lc.MJD,lc.Mag,yerr=lc.Magerr,fmt='.r',label='SN')
plt.legend(fontsize=12)
plt.xlabel('MJD')
plt.ylabel('Mag')

plt.subplot(224)
lc = transient_lc[transient_lc['ID']=='TranID1104291400294112297']
plt.errorbar(lc.MJD,lc.Mag,yerr=lc.Magerr,fmt='.r',label='SN')
plt.legend(fontsize=12)
plt.xlabel('MJD')
plt.ylabel('Mag')

plt.savefig(results_dir + 'SN.png',bbox_inches="tight") 
plt.show()

# %% [markdown]
# # AGN

# %%
lc_plots(lb='AGN',data=data,max_points=400)
plt.show()
# Out:
# TranID1105130041134149159
# TranID1112291120524129371
# TranID1502081400484121702

# %%
# Plotting the best 4 lc for a specific class

plt.figure(figsize=(22,10))

plt.subplot(221)
lc = transient_lc[transient_lc['ID']=='TranID1112291120524129371']
plt.errorbar(lc.MJD,lc.Mag,yerr=lc.Magerr,fmt='.r',label='AGN')
plt.legend(fontsize=12)
plt.xlabel('MJD')
plt.ylabel('Mag')


plt.subplot(222)
lc = transient_lc[transient_lc['ID']=='TranID1105130041134149159']
plt.errorbar(lc.MJD,lc.Mag,yerr=lc.Magerr,fmt='.r',label='AGN')
plt.legend(fontsize=12)
plt.xlabel('MJD')
plt.ylabel('Mag')

plt.subplot(223)
lc = transient_lc[transient_lc['ID']=='TranID1011081230504119481']
plt.errorbar(lc.MJD,lc.Mag,yerr=lc.Magerr,fmt='.r',label='AGN')
plt.legend(fontsize=12)
plt.xlabel('MJD')
plt.ylabel('Mag')

plt.subplot(224)
lc = transient_lc[transient_lc['ID']=='TranID1209231181154135712']
plt.errorbar(lc.MJD,lc.Mag,yerr=lc.Magerr,fmt='.r',label='AGN')
plt.legend(fontsize=12)
plt.xlabel('MJD')
plt.ylabel('Mag')

plt.savefig(results_dir + 'AGN.png',bbox_inches="tight") 
plt.show()

# %% [markdown]
# # CV

# %%
lc_plots(lb='CV',data=data,max_points=400)
plt.show()
# Out:
# TranID1002171210554127510
# TranID1005221320424122472
# TranID1303151210504145839
# TranID1312241350384110624
# TranID1610071320374137623
# TranID801301180474127786
# TranID803241120274139158
# TranID904021180524130924
# TranID909221290444111464
# TranID909301120444140061

# %%
# Plotting the best 4 lc for a specific class

plt.figure(figsize=(22,10))

plt.subplot(221)
lc = transient_lc[transient_lc['ID']=='TranID803241120274139158']
plt.errorbar(lc.MJD,lc.Mag,yerr=lc.Magerr,fmt='.r',label='CV')
plt.legend(fontsize=12)
plt.xlabel('MJD')
plt.ylabel('Mag')


plt.subplot(222)
lc = transient_lc[transient_lc['ID']=='TranID1002171210554127510']
plt.errorbar(lc.MJD,lc.Mag,yerr=lc.Magerr,fmt='.r',label='CV')
plt.legend(fontsize=12)
plt.xlabel('MJD')
plt.ylabel('Mag')

plt.subplot(223)
lc = transient_lc[transient_lc['ID']=='TranID1005221320424122472']
plt.errorbar(lc.MJD,lc.Mag,yerr=lc.Magerr,fmt='.r',label='CV')
plt.legend(fontsize=12)
plt.xlabel('MJD')
plt.ylabel('Mag')

plt.subplot(224)
lc = transient_lc[transient_lc['ID']=='TranID909221290444111464']
plt.errorbar(lc.MJD,lc.Mag,yerr=lc.Magerr,fmt='.r',label='CV')
plt.legend(fontsize=12)
plt.xlabel('MJD')
plt.ylabel('Mag')

plt.savefig(results_dir + 'CV.png',bbox_inches="tight") 
plt.show()

# %% [markdown]
# # Balazar

# %%
lc_plots(lb='Blazar',data=data,max_points=300)
plt.show()
# Out:
# TranID1109260070234114098
# TranID1110211321074152444
# TranID1112301380354137481
# TranID1206221121184125294
# TranID1212031040224128186
# TranID1304121230614134803
# TranID1306011120674133862
# TranID1311061010294118517
# TranID1405181150504122960
# TranID1409140071154101822
# TranID1503291260234109459
# TranID1512091151214142650
# TranID1512161181174138560
# TranID1601121290524101185
# TranID1602271120454112778
# TranID1609251231144129676
# TranID906221181134169457

# %%
# Plotting the best 4 lc for a specific class

plt.figure(figsize=(22,10))

plt.subplot(221)
lc = transient_lc[transient_lc['ID']=='TranID1212031040224128186']
plt.errorbar(lc.MJD,lc.Mag,yerr=lc.Magerr,fmt='.r',label='Blazar')
plt.legend(fontsize=12)
plt.xlabel('MJD')
plt.ylabel('Mag')


plt.subplot(222)
lc = transient_lc[transient_lc['ID']=='TranID906221181134169457']
plt.errorbar(lc.MJD,lc.Mag,yerr=lc.Magerr,fmt='.r',label='Blazar')
plt.legend(fontsize=12)
plt.xlabel('MJD')
plt.ylabel('Mag')

plt.subplot(223)
lc = transient_lc[transient_lc['ID']=='TranID1311061010294118517']
plt.errorbar(lc.MJD,lc.Mag,yerr=lc.Magerr,fmt='.r',label='Blazar')
plt.legend(fontsize=12)
plt.xlabel('MJD')
plt.ylabel('Mag')

plt.subplot(224)
lc = transient_lc[transient_lc['ID']=='TranID1109260070234114098']
plt.errorbar(lc.MJD,lc.Mag,yerr=lc.Magerr,fmt='.r',label='Blazar')
plt.legend(fontsize=12)
plt.xlabel('MJD')
plt.ylabel('Mag')

plt.savefig(results_dir + 'Blazar.png',bbox_inches="tight") 
plt.show()

# %% [markdown]
# # Unknown

# %%
lc_plots(lb='Unknown',data=data,max_points=300)
plt.show()
# Out:
# TranID1001081010654134912
# TranID1005131230814132089
# TranID1012031380384133667
# TranID1104051010784130380
# TranID1106241010694118297
# TranID1111011291114153567
# TranID1201271040284172041
# TranID1205161380684113569
# TranID1209171181184108688
# TranID1301131010554139998
# TranID1302171230424139186
# TranID1306201260664112997
# TranID1410011070104121118
# TranID1510311120124112847
# TranID1511201320364108282
# TranID804161350364129084

# %%
# Plotting the best 4 lc for a specific class

plt.figure(figsize=(22,10))

plt.subplot(221)
lc = transient_lc[transient_lc['ID']=='TranID1306201260664112997']
plt.errorbar(lc.MJD,lc.Mag,yerr=lc.Magerr,fmt='.r',label='Unknown')
plt.legend(fontsize=12)
plt.xlabel('MJD')
plt.ylabel('Mag')


plt.subplot(222)
lc = transient_lc[transient_lc['ID']=='TranID1511201320364108282']
plt.errorbar(lc.MJD,lc.Mag,yerr=lc.Magerr,fmt='.r',label='Unknown')
plt.legend(fontsize=12)
plt.xlabel('MJD')
plt.ylabel('Mag')

plt.subplot(223)
lc = transient_lc[transient_lc['ID']=='TranID1104051010784130380']
plt.errorbar(lc.MJD,lc.Mag,yerr=lc.Magerr,fmt='.r',label='Unknown')
plt.legend(fontsize=12)
plt.xlabel('MJD')
plt.ylabel('Mag')

plt.subplot(224)
lc = transient_lc[transient_lc['ID']=='TranID1005131230814132089']
plt.errorbar(lc.MJD,lc.Mag,yerr=lc.Magerr,fmt='.r',label='Unknown')
plt.legend(fontsize=12)
plt.xlabel('MJD')
plt.ylabel('Mag')

plt.savefig(results_dir + 'Unknown.png',bbox_inches="tight") 
plt.show()
